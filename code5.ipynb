# %%
import numpy as np
import seaborn as sns
import os
import cv2
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
# %matplotlib inline

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Input, Conv2D, Concatenate, Dense, Dropout, Flatten, MaxPooling2D, ReLU, AveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.metrics import categorical_crossentropy

# %%
import keras

# %%
train = tf.keras.utils.image_dataset_from_directory('train')
val = tf.keras.utils.image_dataset_from_directory('validation')
test = tf.keras.utils.image_dataset_from_directory('test')
# Out:
# Found 3115 files belonging to 36 classes.
# Found 351 files belonging to 36 classes.

# %%
IMG_WIDTH = 100
IMG_HEIGHT = 100
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory('train',
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 3115 images belonging to 36 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory('validation',
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 351 images belonging to 36 classes.

# %%
train_ds = train_generator
valid_ds = validation_generator

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : apple
# 1 : banana
# 2 : beetroot
# 3 : bell pepper
# 4 : cabbage
# 5 : capsicum
# 6 : carrot
# 7 : cauliflower
# 8 : chilli pepper
# 9 : corn
# 10 : cucumber
# 11 : eggplant
# 12 : garlic
# 13 : ginger
# 14 : grapes
# 15 : jalepeno
# 16 : kiwi
# 17 : lemon
# 18 : lettuce
# 19 : mango
# 20 : onion
# 21 : orange
# 22 : paprika
# 23 : pear
# 24 : peas
# 25 : pineapple
# 26 : pomegranate
# 27 : potato
# 28 : raddish
# 29 : soy beans
# 30 : spinach
# 31 : sweetcorn
# 32 : sweetpotato
# 33 : tomato
# 34 : turnip
# 35 : watermelon

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (128, 100, 100, 3)
# (128, 36)

# %%
def create_conv(img_path='network1.png'):
    inp = Input((100, 100, 3))
    conv2d_1 = Conv2D(
        filters = 16,
        kernel_size = (3, 3),
        strides =(1),
        padding = 'SAME', 
        activation = 'relu')(inp)
    BatchNormalization()
    b1 = BatchNormalization()(conv2d_1)
    r1 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b1)
    pool = MaxPooling2D((2,2), padding='same')(r1)

    conv2d_2 = Conv2D(
        filters = 16,
        kernel_size = (5, 5),
        strides =(2),
        padding = 'SAME',
        activation = 'relu')(r1)
    b2 = BatchNormalization()(conv2d_2)
    r2 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b2)
    #first block-----------------

    conv2d_3 = Conv2D(
        filters = 16,
        kernel_size = (3, 3),
        strides =(1),
        padding = 'SAME',
        activation = 'relu')(r2)
    b3 = BatchNormalization()(conv2d_3)
    r3 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b3)
    # r3 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(conv2d_3)
    conv2d_4 = Conv2D(
        filters = 16,
        kernel_size = (5, 5),
        strides =(1),
        padding = 'SAME',
        activation = 'relu')(r2)
    b4 = BatchNormalization()(conv2d_4)
    r4 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b4)
    conv2d_5 = Conv2D(
        filters = 16,
        kernel_size = (7, 7),
        strides =(1),
        padding = 'SAME',
        activation = 'relu')(r2)
    b5 = BatchNormalization()(conv2d_5)
    r5 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b5)
    conv2d_6 = Conv2D(
        filters = 16,
        kernel_size = (11, 11),
        strides =(1),
        padding = 'SAME',
        activation = 'relu')(r2)
    BatchNormalization()
    b6 = BatchNormalization()(conv2d_6)
    r6 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b6)

    CN1 = Concatenate()([r2, r3, r4, r5, r6])
    bx1 = BatchNormalization()(CN1)
    BatchNormalization()
    pool1 = MaxPooling2D((2,2), padding='same')(bx1)

    #Second block-----------------

    conv2d_7 = Conv2D(
        filters = 32,
        kernel_size = (3, 3),
        strides =(2),
        padding = 'SAME',
        activation = 'relu')(bx1)
    BatchNormalization()
    b7 = BatchNormalization()(conv2d_7)
    r7 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b7)
    conv2d_8 = Conv2D(
        filters = 32,
        kernel_size = (5, 5),
        strides =(2),
        padding = 'SAME',
        activation = 'relu')(bx1)
    BatchNormalization()
    b8 = BatchNormalization()(conv2d_8)
    r8 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b8)
    conv2d_9 = Conv2D(
        filters = 32,
        kernel_size = (7, 7),
        strides =(2),
        padding = 'SAME',
        activation = 'relu')(bx1)
    BatchNormalization()
    b9 = BatchNormalization()(conv2d_9)
    r9 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b9)
    conv2d_10 = Conv2D(
        filters = 32,
        kernel_size = (11, 11),
        strides =(2),
        padding = 'SAME',
        activation = 'relu')(bx1)
    b10 = BatchNormalization()(conv2d_10)
    r10 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b10)

    CN2 = Concatenate()([r7, r8, r9, r10])
    bx2 = BatchNormalization()(CN2)
    pool2 = MaxPooling2D((2,2), padding='same')(bx2)

    #Third block-----------------

    conv2d_11 = Conv2D(
        filters = 32,
        kernel_size = (3, 3),
        strides =(1),
        padding = 'SAME',
        activation = 'relu')(bx2)
    b11 = BatchNormalization()(conv2d_11)
    r11 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b11)
    conv2d_12 = Conv2D(
        filters = 32,
        kernel_size = (5, 5),
        strides =(1),
        padding = 'SAME',
        activation = 'relu')(bx2)
    b12 = BatchNormalization()(conv2d_12)
    r12 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b12)
    conv2d_13 = Conv2D(
        filters = 32,
        kernel_size = (7, 7),
        strides =(1),
        padding = 'SAME',
        activation = 'relu')(bx2)
    b13 = BatchNormalization()(conv2d_13)
    r13 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b13)
    conv2d_14 = Conv2D(
        filters = 32,
        kernel_size = (11, 11),
        strides =(1),
        padding = 'SAME',
        activation = 'relu')(bx2)
    b14 = BatchNormalization()(conv2d_14)
    r14 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b14)

    CN3 = Concatenate()([bx2, r11, r12, r13, r14])
    bx3 = BatchNormalization()(CN3)
    pool3 = MaxPooling2D((2,2), padding='same')(bx3)

    #Third block-----------------

    conv2d_15 = Conv2D(
        filters = 64,
        kernel_size = (3, 3),
        strides =(2),
        padding = 'SAME',
        activation = 'relu')(bx3)
    b15 = BatchNormalization()(conv2d_15)
    r15 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b15)
    conv2d_16 = Conv2D(
        filters = 64,
        kernel_size = (5, 5),
        strides =(2),
        padding = 'SAME',
        activation = 'relu')(bx3)
    b16 = BatchNormalization()(conv2d_16)
    r16 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b16)
    conv2d_17 = Conv2D(
        filters = 64,
        kernel_size = (7, 7),
        strides =(2),
        padding = 'SAME',
        activation = 'relu')(bx3)
    b17 = BatchNormalization()(conv2d_17)
    r17 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b17)
    conv2d_18 = Conv2D(
        filters = 64,
        kernel_size = (11, 11),
        strides =(2),
        padding = 'SAME',
        activation = 'relu')(bx3)
    b18 = BatchNormalization()(conv2d_18)
    r18 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b18)

    poolx = MaxPooling2D((8,8), padding='same')(bx1)
    conv2d_19 = Conv2D(
        filters = 64,
        kernel_size = (7, 7),
        strides =(4),
        padding = 'SAME',
        activation = 'relu')(bx1)
    b19 = BatchNormalization()(conv2d_19)
    r19 = ReLU(max_value=None, negative_slope=0.0, threshold=0.0)(b19)


    CN4 = Concatenate()([r15, r16, r17, r18, r19])
    bx4 = BatchNormalization()(CN4)
    
    a1 = AveragePooling2D((7,7), strides= 2)(bx4)
    flatten = Flatten()(a1)
    fc1 = Dense(300, activation='relu')(flatten)
    dropout1 = Dropout(0.5)(fc1)
    fc2 = Dense(200, activation='relu')(dropout1)
    dropout2 = Dropout(0.5)(fc2)
    fc3 = Dense(36, activation='relu')(dropout2)
    output = Dense(36, activation='softmax')(fc3)


    model = tf.keras.models.Model(inputs=inp, outputs=output)
    print(len(model.layers))
    tf.keras.utils.plot_model(model, to_file=img_path)
    return model

# %%
tf.keras.backend.clear_session()

# %%
cnn = create_conv()
# Out:
# 74

# %%
print(cnn.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 100, 100, 16  448         ['input_1[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 100, 100, 16  64         ['conv2d[0][0]']
#  rmalization)                   )
#
#  re_lu (ReLU)                   (None, 100, 100, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 50, 50, 16)   6416        ['re_lu[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 50, 50, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 50, 50, 16)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 50, 50, 16)   2320        ['re_lu_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 50, 50, 16)   6416        ['re_lu_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 50, 50, 16)   12560       ['re_lu_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 50, 50, 16)   30992       ['re_lu_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 50, 50, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 50, 50, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 50, 50, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 50, 50, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 50, 50, 16)   0           ['batch_normalization_3[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 50, 50, 16)   0           ['batch_normalization_4[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 50, 50, 16)   0           ['batch_normalization_5[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 50, 50, 16)   0           ['batch_normalization_7[0][0]']
#
#  concatenate (Concatenate)      (None, 50, 50, 80)   0           ['re_lu_1[0][0]',
#                                                                   're_lu_2[0][0]',
#                                                                   're_lu_3[0][0]',
#                                                                   're_lu_4[0][0]',
#                                                                   're_lu_5[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 50, 50, 80)  320         ['concatenate[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 25, 25, 32)   23072       ['batch_normalization_8[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 25, 25, 32)   64032       ['batch_normalization_8[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 25, 25, 32)   125472      ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 25, 25, 32)   309792      ['batch_normalization_8[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 25, 25, 32)  128         ['conv2d_6[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 25, 25, 32)  128         ['conv2d_7[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 25, 25, 32)  128         ['conv2d_8[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 25, 25, 32)  128         ['conv2d_9[0][0]']
#  ormalization)
#
#  re_lu_6 (ReLU)                 (None, 25, 25, 32)   0           ['batch_normalization_11[0][0]']
#
#  re_lu_7 (ReLU)                 (None, 25, 25, 32)   0           ['batch_normalization_13[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 25, 25, 32)   0           ['batch_normalization_15[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 25, 25, 32)   0           ['batch_normalization_16[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 25, 25, 128)  0           ['re_lu_6[0][0]',
#                                                                   're_lu_7[0][0]',
#                                                                   're_lu_8[0][0]',
#                                                                   're_lu_9[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 25, 25, 128)  512        ['concatenate_1[0][0]']
#  ormalization)
#
#  conv2d_10 (Conv2D)             (None, 25, 25, 32)   36896       ['batch_normalization_17[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 25, 25, 32)   102432      ['batch_normalization_17[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 25, 25, 32)   200736      ['batch_normalization_17[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 25, 25, 32)   495648      ['batch_normalization_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 25, 25, 32)  128         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 25, 25, 32)  128         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 25, 25, 32)  128         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 25, 25, 32)  128         ['conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 25, 25, 32)   0           ['batch_normalization_18[0][0]']
#
#  re_lu_11 (ReLU)                (None, 25, 25, 32)   0           ['batch_normalization_19[0][0]']
#
#  re_lu_12 (ReLU)                (None, 25, 25, 32)   0           ['batch_normalization_20[0][0]']
#
#  re_lu_13 (ReLU)                (None, 25, 25, 32)   0           ['batch_normalization_21[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 25, 25, 256)  0           ['batch_normalization_17[0][0]',
#                                                                   're_lu_10[0][0]',
#                                                                   're_lu_11[0][0]',
#                                                                   're_lu_12[0][0]',
#                                                                   're_lu_13[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 25, 25, 256)  1024       ['concatenate_2[0][0]']
#  ormalization)
#
#  conv2d_14 (Conv2D)             (None, 13, 13, 64)   147520      ['batch_normalization_22[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 13, 13, 64)   409664      ['batch_normalization_22[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 13, 13, 64)   802880      ['batch_normalization_22[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 13, 13, 64)   1982528     ['batch_normalization_22[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 13, 13, 64)   250944      ['batch_normalization_8[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 13, 13, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 13, 13, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 13, 13, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 13, 13, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 13, 13, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 13, 13, 64)   0           ['batch_normalization_23[0][0]']
#
#  re_lu_15 (ReLU)                (None, 13, 13, 64)   0           ['batch_normalization_24[0][0]']
#
#  re_lu_16 (ReLU)                (None, 13, 13, 64)   0           ['batch_normalization_25[0][0]']
#
#  re_lu_17 (ReLU)                (None, 13, 13, 64)   0           ['batch_normalization_26[0][0]']
#
#  re_lu_18 (ReLU)                (None, 13, 13, 64)   0           ['batch_normalization_27[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 13, 13, 320)  0           ['re_lu_14[0][0]',
#                                                                   're_lu_15[0][0]',
#                                                                   're_lu_16[0][0]',
#                                                                   're_lu_17[0][0]',
#                                                                   're_lu_18[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 13, 13, 320)  1280       ['concatenate_3[0][0]']
#  ormalization)
#
#  average_pooling2d (AveragePool  (None, 4, 4, 320)   0           ['batch_normalization_28[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 5120)         0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 300)          1536300     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 300)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 200)          60200       ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 200)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 36)           7236        ['dropout_1[0][0]']
#
#  dense_3 (Dense)                (None, 36)           1332        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 6,621,660
# Trainable params: 6,618,748
# Non-trainable params: 2,912
# __________________________________________________________________________________________________
# None

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %%
optimizer = Adam(learning_rate=0.001)

# %%
cnn.compile(optimizer=optimizer,
              loss=CategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
history = cnn.fit(train_generator, epochs=100, validation_data=validation_generator,
                       verbose=2)
# Out:
# Epoch 1/100
# 25/25 - 277s - loss: 3.8520 - accuracy: 0.0360 - val_loss: 3.6027 - val_accuracy: 0.0313 - 277s/epoch - 11s/step
# Epoch 2/100
# 25/25 - 262s - loss: 3.6210 - accuracy: 0.0507 - val_loss: 3.5896 - val_accuracy: 0.0399 - 262s/epoch - 10s/step
# Epoch 3/100
# 25/25 - 261s - loss: 3.5207 - accuracy: 0.0709 - val_loss: 3.6093 - val_accuracy: 0.0313 - 261s/epoch - 10s/step
# Epoch 4/100
# 25/25 - 262s - loss: 3.4141 - accuracy: 0.0921 - val_loss: 3.7634 - val_accuracy: 0.0313 - 262s/epoch - 10s/step
# Epoch 5/100
# 25/25 - 261s - loss: 3.3239 - accuracy: 0.1127 - val_loss: 3.5798 - val_accuracy: 0.0484 - 261s/epoch - 10s/step
# Epoch 6/100
# 25/25 - 261s - loss: 3.2312 - accuracy: 0.1255 - val_loss: 3.6773 - val_accuracy: 0.0285 - 261s/epoch - 10s/step
# Epoch 7/100
# 25/25 - 261s - loss: 3.1059 - accuracy: 0.1441 - val_loss: 4.1398 - val_accuracy: 0.0285 - 261s/epoch - 10s/step
# Epoch 8/100
# 25/25 - 262s - loss: 2.9923 - accuracy: 0.1647 - val_loss: 4.3841 - val_accuracy: 0.0427 - 262s/epoch - 10s/step
# Epoch 9/100
# 25/25 - 261s - loss: 2.9137 - accuracy: 0.1705 - val_loss: 3.6517 - val_accuracy: 0.0769 - 261s/epoch - 10s/step
# Epoch 10/100
# 25/25 - 261s - loss: 2.8686 - accuracy: 0.1772 - val_loss: 4.6224 - val_accuracy: 0.0313 - 261s/epoch - 10s/step
# Epoch 11/100
# 25/25 - 259s - loss: 2.7269 - accuracy: 0.2080 - val_loss: 4.1545 - val_accuracy: 0.0399 - 259s/epoch - 10s/step
# Epoch 12/100
# 25/25 - 262s - loss: 2.6868 - accuracy: 0.2276 - val_loss: 3.7303 - val_accuracy: 0.0712 - 262s/epoch - 10s/step
# Epoch 13/100
# 25/25 - 260s - loss: 2.6204 - accuracy: 0.2327 - val_loss: 3.7551 - val_accuracy: 0.0826 - 260s/epoch - 10s/step
# Epoch 14/100
# 25/25 - 259s - loss: 2.5375 - accuracy: 0.2372 - val_loss: 3.7941 - val_accuracy: 0.0883 - 259s/epoch - 10s/step
# Epoch 15/100
# 25/25 - 259s - loss: 2.4999 - accuracy: 0.2520 - val_loss: 3.1003 - val_accuracy: 0.1481 - 259s/epoch - 10s/step
# Epoch 16/100
# 25/25 - 266s - loss: 2.4532 - accuracy: 0.2722 - val_loss: 2.9638 - val_accuracy: 0.2137 - 266s/epoch - 11s/step
# Epoch 17/100
# 25/25 - 265s - loss: 2.3998 - accuracy: 0.2883 - val_loss: 2.8338 - val_accuracy: 0.2251 - 265s/epoch - 11s/step
# Epoch 18/100
# 25/25 - 265s - loss: 2.3762 - accuracy: 0.2931 - val_loss: 2.6636 - val_accuracy: 0.2621 - 265s/epoch - 11s/step
# Epoch 19/100
# 25/25 - 264s - loss: 2.2982 - accuracy: 0.3152 - val_loss: 2.3780 - val_accuracy: 0.2991 - 264s/epoch - 11s/step
# Epoch 20/100
# 25/25 - 264s - loss: 2.2762 - accuracy: 0.3191 - val_loss: 2.2119 - val_accuracy: 0.4046 - 264s/epoch - 11s/step
# Epoch 21/100
# 25/25 - 261s - loss: 2.2103 - accuracy: 0.3480 - val_loss: 2.9466 - val_accuracy: 0.2080 - 261s/epoch - 10s/step
# Epoch 22/100
# 25/25 - 260s - loss: 2.1806 - accuracy: 0.3429 - val_loss: 1.9642 - val_accuracy: 0.4530 - 260s/epoch - 10s/step
# Epoch 23/100
# 25/25 - 259s - loss: 2.1056 - accuracy: 0.3663 - val_loss: 1.7431 - val_accuracy: 0.4843 - 259s/epoch - 10s/step
# Epoch 24/100
# 25/25 - 259s - loss: 2.0689 - accuracy: 0.3701 - val_loss: 1.7159 - val_accuracy: 0.4929 - 259s/epoch - 10s/step
# Epoch 25/100
# 25/25 - 264s - loss: 2.0301 - accuracy: 0.3942 - val_loss: 1.6093 - val_accuracy: 0.5014 - 264s/epoch - 11s/step
# Epoch 26/100
# 25/25 - 261s - loss: 1.9891 - accuracy: 0.4048 - val_loss: 1.4969 - val_accuracy: 0.5470 - 261s/epoch - 10s/step
# Epoch 27/100
# 25/25 - 263s - loss: 1.9382 - accuracy: 0.4119 - val_loss: 1.8906 - val_accuracy: 0.4416 - 263s/epoch - 11s/step
# Epoch 28/100
# 25/25 - 260s - loss: 1.9544 - accuracy: 0.4045 - val_loss: 1.5546 - val_accuracy: 0.5356 - 260s/epoch - 10s/step
# Epoch 29/100
# 25/25 - 259s - loss: 1.9072 - accuracy: 0.4209 - val_loss: 1.8914 - val_accuracy: 0.4615 - 259s/epoch - 10s/step
# Epoch 30/100
# 25/25 - 259s - loss: 1.8643 - accuracy: 0.4199 - val_loss: 1.2810 - val_accuracy: 0.5983 - 259s/epoch - 10s/step
# Epoch 31/100
# 25/25 - 262s - loss: 1.8337 - accuracy: 0.4501 - val_loss: 2.2678 - val_accuracy: 0.3561 - 262s/epoch - 10s/step
# Epoch 32/100
# 25/25 - 259s - loss: 1.8463 - accuracy: 0.4424 - val_loss: 1.5680 - val_accuracy: 0.5128 - 259s/epoch - 10s/step
# Epoch 33/100
# 25/25 - 259s - loss: 1.7660 - accuracy: 0.4594 - val_loss: 1.5105 - val_accuracy: 0.5641 - 259s/epoch - 10s/step
# Epoch 34/100
# 25/25 - 260s - loss: 1.6926 - accuracy: 0.4989 - val_loss: 1.1207 - val_accuracy: 0.6866 - 260s/epoch - 10s/step
# Epoch 35/100
# 25/25 - 258s - loss: 1.7082 - accuracy: 0.4767 - val_loss: 1.2363 - val_accuracy: 0.6182 - 258s/epoch - 10s/step
# Epoch 36/100
# 25/25 - 259s - loss: 1.6459 - accuracy: 0.4883 - val_loss: 1.1361 - val_accuracy: 0.6553 - 259s/epoch - 10s/step
# Epoch 37/100
# 25/25 - 260s - loss: 1.5608 - accuracy: 0.5098 - val_loss: 1.2313 - val_accuracy: 0.6239 - 260s/epoch - 10s/step
# Epoch 38/100
# 25/25 - 259s - loss: 1.5307 - accuracy: 0.5252 - val_loss: 1.5834 - val_accuracy: 0.5385 - 259s/epoch - 10s/step
# Epoch 39/100

# %%
# Save the trained model
cnn.save('model.h1')

# %%
test_loss, test_acc = cnn.evaluate(test)
print('Test accuracy:', test_acc)
